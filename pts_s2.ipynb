# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df=pd.read_csv('/content/gdrive/MyDrive/dataset/world_population_data.csv')

# %%
df
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
df.head(2) #menampilkan data dari atas yg berjumlah 2 baris
# Out:
#    rank cca3 country continent  2023 population  2022 population  \
# 0     1  IND   India      Asia       1428627663       1417173173
# 1     2  CHN   China      Asia       1425671352       1425887337
#
#    2020 population  2015 population  2010 population  2000 population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
#
#    1990 population  1980 population  1970 population  area (km²)  \
# 0        870452165        696828385        557501301   3287590.0
# 1       1153704252        982372466        822534450   9706961.0
#
#    density (km²) growth rate world percentage
# 0            481       0.81%           17.85%
# 1            151      -0.02%           17.81%

# %%
df.tail(3) #menampilkan data dari bawah yg berjumlah 3 baris
# Out:
#      rank cca3       country continent  2023 population  2022 population  \
# 231   232  NIU          Niue   Oceania             1935             1934
# 232   233  TKL       Tokelau   Oceania             1893             1871
# 233   234  VAT  Vatican City    Europe              518              510
#
#      2020 population  2015 population  2010 population  2000 population  \
# 231             1942             1847             1812             2074
# 232             1827             1454             1367             1666
# 233              520              564              596              651
#
#      1990 population  1980 population  1970 population  area (km²)  \
# 231             2533             3637             5185      261.00
# 232             1669             1647             1714       12.00
# 233              700              733              752        0.44
#
#      density (km²) growth rate world percentage
# 231              7       0.05%            0.00%
# ...

# %%
df.shape #jumlah baris dan kolom
# Out:
# (234, 17)

# %%
print('number  of rows' , df.shape[0])
print('number  of rows' , df.shape[1])
# Out:
# number  of rows 234
# number  of rows 17

# %%
df.info() #info data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              234 non-null    int64
#  1   cca3              234 non-null    object
#  2   country           234 non-null    object
#  3   continent         234 non-null    object
#  4   2023 population   234 non-null    int64
#  5   2022 population   234 non-null    int64
#  6   2020 population   234 non-null    int64
#  7   2015 population   234 non-null    int64
#  8   2010 population   234 non-null    int64
#  9   2000 population   234 non-null    int64
#  10  1990 population   234 non-null    int64
#  11  1980 population   234 non-null    int64
#  12  1970 population   234 non-null    int64
#  13  area (km²)        234 non-null    float64
#  14  density (km²)     234 non-null    int64
#  15  growth rate       234 non-null    object
# ...

# %%
 df.isnull().sum() #mengidentifikasi nilai-nilai yang hilang (NaN/null)
# Out:
# rank                0
# cca3                0
# country             0
# continent           0
# 2023 population     0
# 2022 population     0
# 2020 population     0
# 2015 population     0
# 2010 population     0
# 2000 population     0
# 1990 population     0
# 1980 population     0
# 1970 population     0
# area (km²)          0
# density (km²)       0
# growth rate         0
# world percentage    0
# dtype: int64

# %%
df.isnull() #
# Out:
#       rank   cca3  country  continent  2023 population  2022 population  \
# 0    False  False    False      False            False            False
# 1    False  False    False      False            False            False
# 2    False  False    False      False            False            False
# 3    False  False    False      False            False            False
# 4    False  False    False      False            False            False
# ..     ...    ...      ...        ...              ...              ...
# 229  False  False    False      False            False            False
# 230  False  False    False      False            False            False
# 231  False  False    False      False            False            False
# 232  False  False    False      False            False            False
# 233  False  False    False      False            False            False
#
#      2020 population  2015 population  2010 population  2000 population  \
# ...

# %%
df.describe() #memberikan ringkasan statistik deskriptif untuk kolom-kolom numerik
# Out:
#              rank  2023 population  2022 population  2020 population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.437442e+07     3.407441e+07     3.350107e+07
# std     67.694165     1.373864e+08     1.367664e+08     1.355899e+08
# min      1.000000     5.180000e+02     5.100000e+02     5.200000e+02
# 25%     59.250000     4.225982e+05     4.197385e+05     4.152845e+05
# 50%    117.500000     5.643895e+06     5.559944e+06     5.493074e+06
# 75%    175.750000     2.324537e+07     2.247650e+07     2.144798e+07
# max    234.000000     1.428628e+09     1.425887e+09     1.424930e+09
#
#        2015 population  2010 population  2000 population  1990 population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      3.172996e+07     2.984524e+07     2.626947e+07     2.271022e+07
# std       1.304050e+08     1.242185e+08     1.116982e+08     9.783217e+07
# ...

# %%
df.size #jumlah elemen total
# Out:
# 3978

# %%
 df.dtypes#tipe data setiap kolom
# Out:
# rank                  int64
# cca3                 object
# country              object
# continent            object
# 2023 population       int64
# 2022 population       int64
# 2020 population       int64
# 2015 population       int64
# 2010 population       int64
# 2000 population       int64
# 1990 population       int64
# 1980 population       int64
# 1970 population       int64
# area (km²)          float64
# density (km²)         int64
# growth rate          object
# world percentage     object
# dtype: object

# %%
df[df.duplicated()] #cek data yg ada duplikatnya
# Out:
# Empty DataFrame
# Columns: [rank, cca3, country, continent, 2023 population, 2022 population, 2020 population, 2015 population, 2010 population, 2000 population, 1990 population, 1980 population, 1970 population, area (km²), density (km²), growth rate, world percentage]
# Index: []

# %%
df.describe(include='all') #menghasilkan ringkasan statistik
# Out:
#               rank cca3 country continent  2023 population  2022 population  \
# count   234.000000  234     234       234     2.340000e+02     2.340000e+02
# unique         NaN  234     234         6              NaN              NaN
# top            NaN  IND   India    Africa              NaN              NaN
# freq           NaN    1       1        57              NaN              NaN
# mean    117.500000  NaN     NaN       NaN     3.437442e+07     3.407441e+07
# std      67.694165  NaN     NaN       NaN     1.373864e+08     1.367664e+08
# min       1.000000  NaN     NaN       NaN     5.180000e+02     5.100000e+02
# 25%      59.250000  NaN     NaN       NaN     4.225982e+05     4.197385e+05
# 50%     117.500000  NaN     NaN       NaN     5.643895e+06     5.559944e+06
# 75%     175.750000  NaN     NaN       NaN     2.324537e+07     2.247650e+07
# max     234.000000  NaN     NaN       NaN     1.428628e+09     1.425887e+09
#
# ...

# %%
df['cca3'].unique() #menampilkan kolom tertentu
# Out:
# array(['IND', 'CHN', 'USA', 'IDN', 'PAK', 'NGA', 'BRA', 'BGD', 'RUS',
#        'MEX', 'ETH', 'JPN', 'PHL', 'EGY', 'COD', 'VNM', 'IRN', 'TUR',
#        'DEU', 'THA', 'GBR', 'TZA', 'FRA', 'ZAF', 'ITA', 'KEN', 'MMR',
#        'COL', 'KOR', 'UGA', 'SDN', 'ESP', 'ARG', 'DZA', 'IRQ', 'AFG',
#        'POL', 'CAN', 'MAR', 'SAU', 'UKR', 'AGO', 'UZB', 'YEM', 'PER',
#        'MYS', 'GHA', 'MOZ', 'NPL', 'MDG', 'CIV', 'VEN', 'CMR', 'NER',
#        'AUS', 'PRK', 'TWN', 'MLI', 'BFA', 'SYR', 'LKA', 'MWI', 'ZMB',
#        'ROU', 'CHL', 'KAZ', 'TCD', 'ECU', 'SOM', 'GTM', 'SEN', 'NLD',
#        'KHM', 'ZWE', 'GIN', 'RWA', 'BEN', 'BDI', 'TUN', 'BOL', 'HTI',
#        'BEL', 'JOR', 'DOM', 'CUB', 'SSD', 'SWE', 'HND', 'CZE', 'AZE',
#        'GRC', 'PNG', 'PRT', 'HUN', 'TJK', 'ARE', 'BLR', 'ISR', 'TGO',
#        'AUT', 'CHE', 'SLE', 'LAO', 'HKG', 'SRB', 'NIC', 'LBY', 'PRY',
#        'KGZ', 'BGR', 'TKM', 'SLV', 'COG', 'SGP', 'DNK', 'SVK', 'CAF',
# ...

# %%
df[df['rank']>=100] #menampilkan rank lebih 100
# Out:
#      rank cca3           country      continent  2023 population  \
# 99    100  AUT           Austria         Europe          8958960
# 100   101  CHE       Switzerland         Europe          8796669
# 101   102  SLE      Sierra Leone         Africa          8791092
# 102   103  LAO              Laos           Asia          7633779
# 103   104  HKG         Hong Kong           Asia          7491609
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 99           8939617          8907777          8642421          8362829
# ...

# %%
len(df[(df['rank']>=100)  &  (df['rank']<=200)]) #jumlah baris lebih dari 100 dan kurang 200
# Out:
# 101

# %%
sum(df['rank'].between(90,100)) #berapa baris antara 90 -100
# Out:
# 11

# %%
df['rank'].mean() #rata rata kolom rank
# Out:
# 117.5

# %%
df['rank'].min() #nilai minimum rank
# Out:
# 1

# %%
df['rank'].max() #nilai max rank
# Out:
# 234

# %%
def rank(x):
  return x//2 #membagi nilai input dengan 2

# %%
df['half_marks']=df['rank'].apply(rank) #kolom baru bernama 'half_marks'

# %%
df
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
df['rank'].apply(lambda x:x/2)
# Out:
# 0        0.5
# 1        1.0
# 2        1.5
# 3        2.0
# 4        2.5
#        ...
# 229    115.0
# 230    115.5
# 231    116.0
# 232    116.5
# 233    117.0
# Name: rank, Length: 234, dtype: float64

# %%
df['cca3'].apply(len) # menghitung panjang jumlah karakter
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 229    3
# 230    3
# 231    3
# 232    3
# 233    3
# Name: cca3, Length: 234, dtype: int64

# %%
df
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
df['Asia_North_Amerika']=df['continent'].map({'Asia':1,'North America':0}) # menambahkan kolom baru bernama 'Asia_North_America' yang memetakan nilai-nilai dari kolom 'continent' ke nilai-nilai 1 dan 0

# %%
df
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
df.drop('half_marks',axis=1) #hapus kolom half_marks
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
df.columns #menampilkan nama column
# Out:
# Index(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage', 'half_marks', 'Asia_North_Amerika'],
#       dtype='object')

# %%
df.index #menampilkan baris pada table
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
df.sort_values(by='2023 population') #urutkan berdasarkan nilai terkecil
# Out:
#      rank cca3           country      continent  2023 population  \
# 233   234  VAT      Vatican City         Europe              518
# 232   233  TKL           Tokelau        Oceania             1893
# 231   232  NIU              Niue        Oceania             1935
# 230   231  FLK  Falkland Islands  South America             3791
# 229   230  MSR        Montserrat  North America             4386
# ..    ...  ...               ...            ...              ...
# 4       5  PAK          Pakistan           Asia        240485658
# 3       4  IDN         Indonesia           Asia        277534122
# 2       3  USA     United States  North America        339996563
# 1       2  CHN             China           Asia       1425671352
# 0       1  IND             India           Asia       1428627663
#
#      2022 population  2020 population  2015 population  2010 population  \
# 233              510              520              564              596
# ...

# %%
df.isnull().sum() #cek value yg null
# Out:
# rank                0
# cca3                0
# country             0
# continent           0
# 2023 population     0
# 2022 population     0
# 2020 population     0
# 2015 population     0
# 2010 population     0
# 2000 population     0
# 1990 population     0
# 1980 population     0
# 1970 population     0
# area (km²)          0
# density (km²)       0
# growth rate         0
# world percentage    0
# dtype: int64

# %%
len(df) #cek ada berapa baris
# Out:
# 234

# %%
df[df['continent']=="Asia"] #menampilkan continent khusus Asia
# Out:
#      rank cca3               country continent  2023 population  \
# 0       1  IND                 India      Asia       1428627663
# 1       2  CHN                 China      Asia       1425671352
# 3       4  IDN             Indonesia      Asia        277534122
# 4       5  PAK              Pakistan      Asia        240485658
# 7       8  BGD            Bangladesh      Asia        172954319
# 11     12  JPN                 Japan      Asia        123294513
# 12     13  PHL           Philippines      Asia        117337368
# 15     16  VNM               Vietnam      Asia         98858950
# 16     17  IRN                  Iran      Asia         89172767
# 17     18  TUR                Turkey      Asia         85816199
# 19     20  THA              Thailand      Asia         71801279
# 26     27  MMR               Myanmar      Asia         54577997
# 28     29  KOR           South Korea      Asia         51784059
# 34     35  IRQ                  Iraq      Asia         45504560
# ...

# %%
(df['continent']=="Asia") & (df['2023 population']>19606633) #menyortir data yg continent asia dan 2023 population lebih dari 19606633
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Length: 234, dtype: bool

# %%
df['rank'].value_counts() #menghitung jumlah kemunculan nilai
# Out:
# 1      1
# 161    1
# 149    1
# 150    1
# 151    1
#       ..
# 83     1
# 84     1
# 85     1
# 86     1
# 234    1
# Name: rank, Length: 234, dtype: int64

# %%
df.groupby('rank').mean()['2023 population'] #menghitung rata-rata '2023 population' untuk setiap kelompok 'rank'
# Out:
# <ipython-input-33-a119b22d45e6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('rank').mean()['2023 population']
# rank
# 1      1.428628e+09
# 2      1.425671e+09
# 3      3.399966e+08
# 4      2.775341e+08
# 5      2.404857e+08
#            ...
# 230    4.386000e+03
# 231    3.791000e+03
# 232    1.935000e+03
# 233    1.893000e+03
# 234    5.180000e+02
# Name: 2023 population, Length: 234, dtype: float64

# %%
import seaborn as sns ##seaborn cek null

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
df['continent'].value_counts().plot(kind='bar') ##menampilkan continent dalam bentuk diagram batang
# Out:
# <Axes: >

# %%
df['cca3'].value_counts().plot(kind='bar') ##menampilkan cca3 dalam bentuk diagram batang
# Out:
# <Axes: >
